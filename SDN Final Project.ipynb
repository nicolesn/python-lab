# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings
import re

from sklearn.datasets import make_multilabel_classification
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import CCA
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer 

from nltk.stem import PorterStemmer

# %matplotlib inline

# %%
cchange = pd.read_csv("/Users/apple/Documents/amazon fire_climate change.csv")
ffire = pd.read_csv("/Users/apple/Documents/amazon forest fire.csv")
aforest = pd.read_csv("/Users/apple/Documents/amazon forest.csv")
brazil = pd.read_csv("/Users/apple/Documents/brazil amazon.csv")
brazil.shape
# Out:
# (1456, 31)

# %%
df = cchange.append([ffire, aforest, brazil])
df.tweet
# Out:
# 0       The growing impact of climate change can even ...
# 1       Yes people this is what I was tryna say, pleas...
# 2       Amazon forest is on the brink of self-deforest...
# 3       @Timcast evidence of the amazon forest fire be...
# 4       @Timcast evidence of the amazon forest fire be...
#                               ...
# 1451    Brazil And The Amazon | Patriot Act with Hasan...
# 1452    A problem he cant solve"? \nCO2 emmissions?\n\...
# 1453    . @awscloud do you have a time line for suppor...
# 1454    On the front lines of Bolsonaro’s war on the A...
# 1455    Of course Brazil has its sovereignty and that ...
# Name: tweet, Length: 7418, dtype: object

# %%
ndf = df[['id', 'date', 'username', 'tweet', 'hashtags', 'replies_count', 'retweets_count', 'likes_count']]
ndf
# Out:
#                        id        date         username  \
# 0     1204076740806471680  2019-12-09         isaynews
# 1     1200321224603127808  2019-11-29      kesha_ayres
# 2     1198074985035649024  2019-11-23     pinkbells360
# 3     1194336138166784001  2019-11-12       jacqui_osz
# 4     1194336030826127365  2019-11-12       jacqui_osz
# ...                   ...         ...              ...
# 1451  1205100403353894912  2019-12-12  welovetheearth1
# 1452  1205098738387165185  2019-12-12     dani71533521
# 1453  1205083965520072704  2019-12-12     yellowbrickc
# 1454  1205081801997398016  2019-12-12      rpujolvives
# 1455  1205072416805965826  2019-12-12     mikiefan2013
#
#                                                   tweet  \
# 0     The growing impact of climate change can even ...
# 1     Yes people this is what I was tryna say, pleas...
# 2     Amazon forest is on the brink of self-deforest...
# 3     @Timcast evidence of the amazon forest fire be...
# ...

# %%
from nltk.corpus import stopwords
stemmer = PorterStemmer ()

TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"
stop_words = stopwords.words("english")

def preprocess(text, stem=False):
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    tokens = []
    for token in text.split():
        if token not in stop_words:
            tokens.append(token)
                
    return " ".join(tokens)

# %%
ndf.tweet = ndf.tweet.apply(lambda x : preprocess(x))
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
ndf.to_csv('newAmazon.csv')
