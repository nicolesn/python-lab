# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

import pandas as pd
import numpy as np
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum( )
ts.plot( )

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# %%
df = pd.read_csv('http://stats.moe.gov.tw/files/detail/107/107_student.csv')

# %%
df.head()
# Out:
#              大專校院校別學生數 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  107 學年度 SY2018-2019        NaN        NaN        NaN        NaN        NaN
# 1                 學校代碼       學校名稱     日間∕進修別        等級別         總計        男生計
# 2                 0001     國立政治大學        D 日       D 博士        965        551
# 3                 0001     國立政治大學        D 日       M 碩士      3,998      1,854
# 4                 0001     國立政治大學        D 日       B 學士      9,630      3,983
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 15  \
# 0        NaN        NaN        NaN        NaN     ...             NaN
# 1        女生計      一年級男生      一年級女生      二年級男生     ...           五年級男生
# 2        414         96         85         82     ...              71
# 3      2,144        624        742        632     ...               -
# 4      5,647        899      1,287        890     ...               -
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1       五年級女生       六年級男生       六年級女生       七年級男生       七年級女生       延修生男生
# 2          52          58          46          74          40           -
# 3           -           -           -           -           -           -
# 4           -           -           -           -           -         326
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0         NaN         NaN         NaN
# 1       延修生女生        縣市名稱         體系別
# 2           -      30 臺北市        1 一般
# 3           -      30 臺北市        1 一般
# 4         463      30 臺北市        1 一般
#
# [5 rows x 25 columns]

# %%
df.loc[1]
# Out:
# 大專校院校別學生數        學校代碼
# Unnamed: 1       學校名稱
# Unnamed: 2     日間∕進修別
# Unnamed: 3        等級別
# Unnamed: 4         總計
# Unnamed: 5        男生計
# Unnamed: 6        女生計
# Unnamed: 7      一年級男生
# Unnamed: 8      一年級女生
# Unnamed: 9      二年級男生
# Unnamed: 10     二年級女生
# Unnamed: 11     三年級男生
# Unnamed: 12     三年級女生
# Unnamed: 13     四年級男生
# Unnamed: 14     四年級女生
# Unnamed: 15     五年級男生
# Unnamed: 16     五年級女生
# Unnamed: 17     六年級男生
# Unnamed: 18     六年級女生
# Unnamed: 19     七年級男生
# Unnamed: 20     七年級女生
# Unnamed: 21     延修生男生
# Unnamed: 22     延修生女生
# Unnamed: 23      縣市名稱
# Unnamed: 24       體系別
# Name: 1, dtype: object

# %%
colnames = df.loc[1].values

# %%
df = df[2:]

# %%
df.head()
# Out:
#   大專校院校別學生數 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 2      0001     國立政治大學        D 日       D 博士        965        551        414
# 3      0001     國立政治大學        D 日       M 碩士      3,998      1,854      2,144
# 4      0001     國立政治大學        D 日       B 學士      9,630      3,983      5,647
# 5      0001     國立政治大學        N 職       M 碩士      1,750        896        854
# 6      0002     國立清華大學        D 日       D 博士      1,664      1,221        443
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 15 Unnamed: 16  \
# 2         96         85         82     ...              71          52
# 3        624        742        632     ...               -           -
# 4        899      1,287        890     ...               -           -
# 5        303        248        253     ...              53          47
# 6        225         99        201     ...             158          50
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 2          58          46          74          40           -           -
# 3           -           -           -           -           -           -
# 4           -           -           -           -         326         463
# 5           -           -           -           -           -           -
# 6         112          43         168          58           -           -
#
#   Unnamed: 23 Unnamed: 24
# 2      30 臺北市        1 一般
# 3      30 臺北市        1 一般
# 4      30 臺北市        1 一般
# 5      30 臺北市        1 一般
# 6      18 新竹市        1 一般
#
# [5 rows x 25 columns]

# %%
edds = df

# %%
eggs[eggs. contains('師範')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-2f9fc9d24433> in <module>
# ----> 1 eggs[eggs. contains('師範')]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'contains'

# %%
df = pd.read_html('https://browser.geekbench.com/mac-benchmarks')

# %%
mac = df[0]

# %%
mac.head()
# Out:
#                                                  Mac  Score  Unnamed: 2
# 0  iMac (27-inch Retina Early 2019) Intel Core i9...   6157         NaN
# 1  iMac (27-inch Retina Early 2019) Intel Core i5...   5800         NaN
# 2  iMac (27-inch Retina Mid 2017) Intel Core i7-7...   5684         NaN
# 3  Mac mini (Late 2018) Intel Core i7-8700B @ 3.2...   5660         NaN
# 4  iMac (27-inch Retina Early 2019) Intel Core i5...   5433         NaN

# %%
mac[mac.Mac.str.contains('15-inch Retina Mid 2015')]
# Out:
#                                                   Mac  Score  Unnamed: 2
# 34  MacBook Pro (15-inch Retina Mid 2015) Intel Co...   4394         NaN
# 35  MacBook Pro (15-inch Retina Mid 2015) Intel Co...   4383         NaN
# 48  MacBook Pro (15-inch Retina Mid 2015) Intel Co...   4115         NaN
# 49  MacBook Pro (15-inch Retina Mid 2015) Intel Co...   4102         NaN
# 66  MacBook Pro (15-inch Retina Mid 2015) Intel Co...   3800         NaN

# %%
mac[mac.Mac.str.contains('13-inch Retina Mid 2015')]
# Out:
# Empty DataFrame
# Columns: [Mac, Score, Unnamed: 2]
# Index: []
